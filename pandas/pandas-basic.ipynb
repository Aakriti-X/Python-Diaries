# %% [markdown]
# # Pandas

# %% [markdown]
# ## Installing and Importing

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ##### data structure of pandas: series,framework,index

# %% [markdown]
# ## Importing numpy

# %%
import numpy as np

# %% [markdown]
# # Working with Series

# %%
   # creating empty series
ser = pd.Series()
print(ser)
   #simple array
data = np.array(['g','e','e','k','s'])
ser=pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
#a simple list
list = ['g','e','e','k','s']
#creating series from a list
ser = pd.Series(list)
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %% [markdown]
# # Reading and Writing CSV files

# %%
data = pd.read_csv("students.csv")                                   
data
# Out:
#     Name  Age  Course  Marks
# 0  Aarav   20  Python     85
# 1   Riya   21  Pandas     92
# 2  Kabir   19  Python     78
# 3  Anaya   20   NumPy     88
